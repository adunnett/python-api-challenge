# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from api_keys import weather_api_key
from scipy.stats import linregress
from sklearn import datasets
from citipy import citipy

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %% [markdown]
# ## Generate Cities List

# %%
lat_long = []
cities = []
lat = np.random.uniform(low=-90.000, high=90.000, size=1500)
long = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_long = zip(lat, long)
for lat_long in lat_long:
    city = citipy.nearest_city(lat_long[0], lat_long[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 623

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create base URL for open weather map API call
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

city_name = []
clouds = []
country = []
dates = []
humidity = []
lat = []
lng = []
max_temp = []
wind = []

counter = 1

print('-'*30)
print("Running Data Retrieval")
print('-'*30)

# Loop through all cities in cities list.
for city in cities:
    
    # Try statement to append calls where values are found.
    try:
        response = requests.get(f'{base_url}&q={city}').json()
        city_name.append(response['name'])
        clouds.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        dates.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        
        print(f'Searching for record {counter} | {city}')
        
        # Increase record counter.
        counter += 1
        
        # Do not exceed API call limit.
        time.sleep(1.01)
        
    # If no record found for city, then skip.
    except:
        print('city weather not found, skipping to next record')
    continue
# Out:
# ------------------------------
# Running Data Retrieval
# ------------------------------
# Searching for record 1 | sao filipe
# Searching for record 2 | nome
# Searching for record 3 | lorengau
# city weather not found, skipping to next record
# Searching for record 4 | cabo san lucas
# Searching for record 5 | barrow
# Searching for record 6 | coquimbo
# Searching for record 7 | gobardanga
# Searching for record 8 | hobart
# city weather not found, skipping to next record
# Searching for record 9 | bend
# Searching for record 10 | chuy
# Searching for record 11 | geraldton
# Searching for record 12 | koutsouras
# Searching for record 13 | beruwala
# Searching for record 14 | jamestown
# Searching for record 15 | charlestown
# Searching for record 16 | ushuaia
# Searching for record 17 | rikitea
# Searching for record 18 | zhanaozen
# city weather not found, skipping to next record
# Searching for record 19 | yellowknife
# Searching for record 20 | palmer
# Searching for record 21 | qaanaaq
# Searching for record 22 | ust-nera
# Searching for record 23 | fuxin
# Searching for record 24 | mataura
# Searching for record 25 | arraial do cabo
# Searching for record 26 | vaini
# Searching for record 27 | murchison
# city weather not found, skipping to next record
# Searching for record 28 | la ronge
# Searching for record 29 | saskylakh
# Searching for record 30 | la paz
# Searching for record 31 | batagay-alyta
# city weather not found, skipping to next record
# Searching for record 32 | busselton
# Searching for record 33 | port hardy
# Searching for record 34 | ayabaca
# Searching for record 35 | ribeira grande
# Searching for record 36 | hermanus
# Searching for record 37 | egvekinot
# Searching for record 38 | soc trang
# Searching for record 39 | laramie
# Searching for record 40 | tingo maria
# Searching for record 41 | avarua
# Searching for record 42 | bayji
# Searching for record 43 | nikolskoye
# Searching for record 44 | cape town
# Searching for record 45 | south bend
# Searching for record 46 | riverton
# Searching for record 47 | atuona
# Searching for record 48 | punta arenas
# Searching for record 49 | bosaso
# Searching for record 50 | rawson
# Searching for record 51 | thompson
# Searching for record 52 | albany
# Searching for record 53 | lebu
# Searching for record 54 | puerto ayora
# Searching for record 55 | kapaa
# Searching for record 56 | stanger
# Searching for record 57 | minbu
# Searching for record 58 | esperance
# city weather not found, skipping to next record
# Searching for record 59 | leningradskiy
# Searching for record 60 | east london
# Searching for record 61 | aljezur
# Searching for record 62 | umm kaddadah
# Searching for record 63 | tautira
# Searching for record 64 | bachaquero
# Searching for record 65 | port elizabeth
# Searching for record 66 | karla
# Searching for record 67 | cururupu
# Searching for record 68 | coihaique
# Searching for record 69 | hithadhoo
# city weather not found, skipping to next record
# Searching for record 70 | rockhampton
# Searching for record 71 | zaoyang
# Searching for record 72 | cayenne
# Searching for record 73 | dondo
# Searching for record 74 | deputatskiy
# city weather not found, skipping to next record
# Searching for record 75 | vestmannaeyjar
# Searching for record 76 | husavik
# Searching for record 77 | castro
# Searching for record 78 | cidreira
# Searching for record 79 | taoudenni
# Searching for record 80 | vestmanna
# Searching for record 81 | dikson
# Searching for record 82 | shingu
# Searching for record 83 | bredasdorp
# Searching for record 84 | ancud
# city weather not found, skipping to next record
# Searching for record 85 | biasca
# Searching for record 86 | thinadhoo
# Searching for record 87 | pochutla
# Searching for record 88 | pisco
# Searching for record 89 | khandbari
# Searching for record 90 | matara
# Searching for record 91 | ternate
# Searching for record 92 | gloversville
# Searching for record 93 | carnarvon
# Searching for record 94 | istok
# Searching for record 95 | saint-philippe
# Searching for record 96 | saint-leu
# Searching for record 97 | antofagasta
# Searching for record 98 | manadhoo
# city weather not found, skipping to next record
# Searching for record 99 | kysyl-syr
# Searching for record 100 | rio grande
# Searching for record 101 | nusaybin
# Searching for record 102 | new norfolk
# Searching for record 103 | harrison
# Searching for record 104 | norman wells
# Searching for record 105 | yerbogachen
# Searching for record 106 | butaritari
# city weather not found, skipping to next record
# Searching for record 107 | bethel
# Searching for record 108 | krasnyy chikoy
# Searching for record 109 | fortuna
# Searching for record 110 | gushikawa
# Searching for record 111 | bilibino
# Searching for record 112 | katsuura
# Searching for record 113 | lompoc
# Searching for record 114 | ryotsu
# Searching for record 115 | jinxiang
# Searching for record 116 | olga
# city weather not found, skipping to next record
# Searching for record 117 | melo
# city weather not found, skipping to next record
# Searching for record 118 | ngorongoro
# Searching for record 119 | palasa
# Searching for record 120 | lagoa
# Searching for record 121 | cravo norte
# Searching for record 122 | tombouctou
# Searching for record 123 | were ilu
# Searching for record 124 | tinskoy
# Searching for record 125 | henties bay
# Searching for record 126 | sitka
# Searching for record 127 | gabriel leyva solano
# Searching for record 128 | airai
# Searching for record 129 | port alfred
# Searching for record 130 | waingapu
# Searching for record 131 | pointe michel
# Searching for record 132 | dingle
# Searching for record 133 | kilindoni
# Searching for record 134 | landskrona
# Searching for record 135 | lethem
# Searching for record 136 | hilo
# Searching for record 137 | vila franca do campo
# Searching for record 138 | nanortalik
# Searching for record 139 | ewa beach
# Searching for record 140 | tapejara
# Searching for record 141 | conakry
# Searching for record 142 | zamania
# Searching for record 143 | ascension
# Searching for record 144 | bengkulu
# city weather not found, skipping to next record
# Searching for record 145 | schruns
# Searching for record 146 | sovetskiy
# Searching for record 147 | kloulklubed
# Searching for record 148 | caravelas
# Searching for record 149 | kaeo
# Searching for record 150 | mar del plata
# city weather not found, skipping to next record
# Searching for record 151 | adet
# Searching for record 152 | rio gallegos
# Searching for record 153 | paamiut
# Searching for record 154 | pathein
# Searching for record 155 | dekar
# Searching for record 156 | cascas
# Searching for record 157 | urengoy
# Searching for record 158 | tiksi
# Searching for record 159 | najran
# Searching for record 160 | conde
# Searching for record 161 | tuktoyaktuk
# Searching for record 162 | parole
# city weather not found, skipping to next record
# Searching for record 163 | amapa
# Searching for record 164 | turayf
# Searching for record 165 | bluff
# city weather not found, skipping to next record
# Searching for record 166 | chokurdakh
# Searching for record 167 | pandan
# Searching for record 168 | mount gambier
# Searching for record 169 | beringovskiy
# Searching for record 170 | severo-kurilsk
# Searching for record 171 | labuhan
# Searching for record 172 | tadine
# Searching for record 173 | akyab
# Searching for record 174 | clyde river
# city weather not found, skipping to next record
# Searching for record 175 | ocos
# Searching for record 176 | camargo
# city weather not found, skipping to next record
# Searching for record 177 | chiredzi
# Searching for record 178 | bambous virieux
# Searching for record 179 | kanlagay
# Searching for record 180 | umea
# Searching for record 181 | jalu
# Searching for record 182 | grand gaube
# Searching for record 183 | praia da vitoria
# city weather not found, skipping to next record
# Searching for record 184 | boqueirao
# Searching for record 185 | dubti
# Searching for record 186 | beatrice
# Searching for record 187 | jardim
# Searching for record 188 | adrar
# Searching for record 189 | saurimo
# Searching for record 190 | statesville
# Searching for record 191 | formosa
# Searching for record 192 | hellvik
# Searching for record 193 | upernavik
# Searching for record 194 | kotelnikovo
# Searching for record 195 | wagar
# Searching for record 196 | raga
# Searching for record 197 | khorixas
# Searching for record 198 | parfenyevo
# Searching for record 199 | provideniya
# Searching for record 200 | curug
# Searching for record 201 | koungou
# Searching for record 202 | kaitangata
# city weather not found, skipping to next record
# Searching for record 203 | lerwick
# Searching for record 204 | amahai
# Searching for record 205 | ganzhou
# Searching for record 206 | vao
# Searching for record 207 | ahmadpur east
# Searching for record 208 | bubaque
# Searching for record 209 | huarmey
# Searching for record 210 | khatanga
# city weather not found, skipping to next record
# Searching for record 211 | port hueneme
# Searching for record 212 | hailar
# Searching for record 213 | tasiilaq
# Searching for record 214 | baykit
# Searching for record 215 | pevek
# Searching for record 216 | san vicente de canete
# Searching for record 217 | puerto padre
# Searching for record 218 | kardamaina
# city weather not found, skipping to next record
# Searching for record 219 | valleyview
# Searching for record 220 | suntar
# city weather not found, skipping to next record
# Searching for record 221 | marsh harbour
# Searching for record 222 | constitucion
# Searching for record 223 | auki
# Searching for record 224 | ahipara
# Searching for record 225 | walvis bay
# city weather not found, skipping to next record
# Searching for record 226 | sao joao da barra
# Searching for record 227 | cabedelo
# Searching for record 228 | ambatofinandrahana
# Searching for record 229 | pontypridd
# Searching for record 230 | narsaq
# Searching for record 231 | las vegas
# Searching for record 232 | ulaanbaatar
# Searching for record 233 | okha
# Searching for record 234 | marawi
# Searching for record 235 | port lincoln
# Searching for record 236 | tecalitlan
# Searching for record 237 | ortona
# Searching for record 238 | yar-sale
# Searching for record 239 | bandarbeyla
# Searching for record 240 | srednekolymsk
# Searching for record 241 | tura
# Searching for record 242 | abu samrah
# city weather not found, skipping to next record
# Searching for record 243 | kodiak
# Searching for record 244 | kulhudhuffushi
# Searching for record 245 | san patricio
# Searching for record 246 | yarega
# Searching for record 247 | alampur
# Searching for record 248 | shahreza
# Searching for record 249 | souillac
# Searching for record 250 | xai-xai
# Searching for record 251 | mabaruma
# city weather not found, skipping to next record
# Searching for record 252 | southbridge
# Searching for record 253 | abalak
# Searching for record 254 | rocha
# Searching for record 255 | loandjili
# Searching for record 256 | guerrero negro
# Searching for record 257 | taonan
# Searching for record 258 | guangyuan
# Searching for record 259 | ivybridge
# Searching for record 260 | baay
# Searching for record 261 | severo-yeniseyskiy
# Searching for record 262 | saint-augustin
# Searching for record 263 | cockburn town
# Searching for record 264 | langfang
# Searching for record 265 | broken hill
# Searching for record 266 | samandag
# Searching for record 267 | tabora
# city weather not found, skipping to next record
# Searching for record 268 | nouadhibou
# Searching for record 269 | bonavista
# Searching for record 270 | faya
# Searching for record 271 | chifeng
# Searching for record 272 | riyadh
# city weather not found, skipping to next record
# Searching for record 273 | ponta do sol
# Searching for record 274 | moramanga
# Searching for record 275 | chimore
# city weather not found, skipping to next record
# Searching for record 276 | zhezkazgan
# Searching for record 277 | honningsvag
# Searching for record 278 | denpasar
# Searching for record 279 | tahoua
# Searching for record 280 | hambantota
# Searching for record 281 | xiaoshi
# Searching for record 282 | vilcun
# Searching for record 283 | mackay
# Searching for record 284 | channel-port aux basques
# Searching for record 285 | karratha
# Searching for record 286 | khani
# Searching for record 287 | northam
# Searching for record 288 | uruzgan
# Searching for record 289 | copiapo
# city weather not found, skipping to next record
# Searching for record 290 | general roca
# Searching for record 291 | samarai
# Searching for record 292 | forest lake
# Searching for record 293 | jarvakandi
# Searching for record 294 | onega
# Searching for record 295 | half moon bay
# Searching for record 296 | quesnel
# Searching for record 297 | pyu
# Searching for record 298 | meulaboh
# Searching for record 299 | aklavik
# Searching for record 300 | pitanga
# Searching for record 301 | poum
# Searching for record 302 | abonnema
# Searching for record 303 | nemuro
# Searching for record 304 | zaysan
# Searching for record 305 | dunedin
# Searching for record 306 | tual
# Searching for record 307 | kahului
# Searching for record 308 | galle
# Searching for record 309 | kabare
# city weather not found, skipping to next record
# city weather not found, skipping to next record
# Searching for record 310 | parasia
# Searching for record 311 | breves
# Searching for record 312 | snezhnogorsk
# Searching for record 313 | lavumisa
# Searching for record 314 | sorland
# city weather not found, skipping to next record
# Searching for record 315 | qui nhon
# Searching for record 316 | twin falls
# Searching for record 317 | longyearbyen
# city weather not found, skipping to next record
# Searching for record 318 | santa isabel
# Searching for record 319 | muyezerskiy
# city weather not found, skipping to next record
# Searching for record 320 | qingyuan
# Searching for record 321 | inirida
# Searching for record 322 | klaksvik
# city weather not found, skipping to next record
# Searching for record 323 | merritt island
# city weather not found, skipping to next record
# city weather not found, skipping to next record
# Searching for record 324 | sterling
# Searching for record 325 | urumqi
# Searching for record 326 | dergachi
# Searching for record 327 | tilichiki
# Searching for record 328 | maniitsoq
# Searching for record 329 | saint george
# Searching for record 330 | ambilobe
# Searching for record 331 | kaoma
# Searching for record 332 | axim
# Searching for record 333 | clearwater
# Searching for record 334 | vardo
# Searching for record 335 | burnie
# Searching for record 336 | los llanos de aridane
# Searching for record 337 | isangel
# Searching for record 338 | weihai
# Searching for record 339 | nalut
# Searching for record 340 | viedma
# Searching for record 341 | phalombe
# Searching for record 342 | west richland
# Searching for record 343 | torbay
# Searching for record 344 | moerai
# city weather not found, skipping to next record
# Searching for record 345 | teya
# Searching for record 346 | calama
# Searching for record 347 | hirara
# city weather not found, skipping to next record
# Searching for record 348 | balotra
# Searching for record 349 | zeya
# city weather not found, skipping to next record
# Searching for record 350 | mahebourg
# Searching for record 351 | aurora
# Searching for record 352 | iralaya
# Searching for record 353 | jumla
# city weather not found, skipping to next record
# Searching for record 354 | liuhe
# Searching for record 355 | necochea
# Searching for record 356 | svetlaya
# Searching for record 357 | aviles
# Searching for record 358 | hohhot
# Searching for record 359 | razole
# Searching for record 360 | pocone
# Searching for record 361 | dickinson
# Searching for record 362 | mitu
# Searching for record 363 | manggar
# Searching for record 364 | ishigaki
# Searching for record 365 | gold coast
# Searching for record 366 | lincoln
# city weather not found, skipping to next record
# Searching for record 367 | mugan
# Searching for record 368 | ardakan
# Searching for record 369 | puerto del rosario
# Searching for record 370 | togur
# Searching for record 371 | sal rei
# Searching for record 372 | alabino
# Searching for record 373 | san cristobal
# Searching for record 374 | aripuana
# Searching for record 375 | mao
# Searching for record 376 | filadelfia
# city weather not found, skipping to next record
# city weather not found, skipping to next record
# Searching for record 377 | mwinilunga
# Searching for record 378 | storsteinnes
# Searching for record 379 | aswan
# city weather not found, skipping to next record
# Searching for record 380 | canovanas
# city weather not found, skipping to next record
# Searching for record 381 | pimentel
# Searching for record 382 | gat
# Searching for record 383 | comodoro rivadavia
# Searching for record 384 | te anau
# Searching for record 385 | zhangjiakou
# Searching for record 386 | saldanha
# Searching for record 387 | ambon
# Searching for record 388 | luderitz
# Searching for record 389 | grojec
# Searching for record 390 | richmond
# Searching for record 391 | meiganga
# Searching for record 392 | sisimiut
# Searching for record 393 | iskateley
# Searching for record 394 | simao
# Searching for record 395 | lydenburg
# city weather not found, skipping to next record
# Searching for record 396 | kitzbuhel
# Searching for record 397 | greencastle
# Searching for record 398 | griffith
# city weather not found, skipping to next record
# Searching for record 399 | agde
# Searching for record 400 | saint anthony
# Searching for record 401 | zemio
# Searching for record 402 | cherskiy
# Searching for record 403 | beya
# city weather not found, skipping to next record
# Searching for record 404 | itarema
# city weather not found, skipping to next record
# Searching for record 405 | avera
# city weather not found, skipping to next record
# Searching for record 406 | osuna
# Searching for record 407 | rassvet
# Searching for record 408 | awjilah
# city weather not found, skipping to next record
# Searching for record 409 | hobyo
# Searching for record 410 | tezu
# Searching for record 411 | kieta
# Searching for record 412 | acapulco
# Searching for record 413 | naze
# city weather not found, skipping to next record
# Searching for record 414 | gunjur
# Searching for record 415 | talnakh
# Searching for record 416 | asau
# Searching for record 417 | kamenka
# Searching for record 418 | sayyan
# city weather not found, skipping to next record
# Searching for record 419 | anloga
# Searching for record 420 | juneau
# Searching for record 421 | oulainen
# Searching for record 422 | loralai
# city weather not found, skipping to next record
# Searching for record 423 | tagusao
# Searching for record 424 | usinsk
# Searching for record 425 | alofi
# Searching for record 426 | pacayas
# Searching for record 427 | noyabrsk
# Searching for record 428 | cochabamba
# Searching for record 429 | ajdabiya
# city weather not found, skipping to next record
# Searching for record 430 | havelock
# Searching for record 431 | angoche
# Searching for record 432 | riberalta
# Searching for record 433 | chara
# Searching for record 434 | presidencia roque saenz pena
# Searching for record 435 | rochester
# Searching for record 436 | sangar
# Searching for record 437 | laela
# Searching for record 438 | mount isa
# Searching for record 439 | melilla
# Searching for record 440 | codrington
# Searching for record 441 | valdivia
# Searching for record 442 | iqaluit
# city weather not found, skipping to next record
# Searching for record 443 | kapuskasing
# Searching for record 444 | abha
# Searching for record 445 | livingstonia
# Searching for record 446 | puerto escondido
# Searching for record 447 | newport
# Searching for record 448 | tabou
# Searching for record 449 | sur
# Searching for record 450 | baculin
# Searching for record 451 | port hedland
# Searching for record 452 | lewistown
# Searching for record 453 | doctor juan manuel frutos
# Searching for record 454 | kidodi
# Searching for record 455 | kruisfontein
# Searching for record 456 | roald
# Searching for record 457 | chilca
# Searching for record 458 | balkanabat
# Searching for record 459 | mbandaka
# Searching for record 460 | savannah bight
# Searching for record 461 | richards bay
# Searching for record 462 | sakakah
# Searching for record 463 | kailua
# Searching for record 464 | kuala lipis
# Searching for record 465 | port macquarie
# Searching for record 466 | hamilton
# Searching for record 467 | takoradi
# Searching for record 468 | kirksville
# city weather not found, skipping to next record
# Searching for record 469 | leh
# Searching for record 470 | poronaysk
# Searching for record 471 | kisangani
# Searching for record 472 | dwarka
# Searching for record 473 | vangaindrano
# Searching for record 474 | port-cartier
# Searching for record 475 | buala
# Searching for record 476 | yulara
# Searching for record 477 | edd
# Searching for record 478 | hofn
# Searching for record 479 | grindavik
# Searching for record 480 | maputi
# Searching for record 481 | belaya gora
# Searching for record 482 | minab
# Searching for record 483 | tobol
# Searching for record 484 | tuatapere
# Searching for record 485 | faanui
# Searching for record 486 | prince george
# Searching for record 487 | broome
# Searching for record 488 | thiruvananthapuram
# Searching for record 489 | kaihua
# Searching for record 490 | san ramon de la nueva oran
# Searching for record 491 | ayacucho
# Searching for record 492 | kawalu
# Searching for record 493 | jos
# Searching for record 494 | shimoda
# Searching for record 495 | zomin
# Searching for record 496 | bilma
# Searching for record 497 | marzuq
# Searching for record 498 | jingdezhen
# Searching for record 499 | martinsburg
# Searching for record 500 | victoria
# Searching for record 501 | kita
# Searching for record 502 | seymchan
# Searching for record 503 | seoul
# Searching for record 504 | parkersburg
# Searching for record 505 | plettenberg bay
# city weather not found, skipping to next record
# Searching for record 506 | boyolangu
# Searching for record 507 | goderich
# Searching for record 508 | boshan
# Searching for record 509 | akcakoca
# Searching for record 510 | traverse city
# Searching for record 511 | malanje
# Searching for record 512 | hasaki
# Searching for record 513 | fort nelson
# Searching for record 514 | lavrentiya
# Searching for record 515 | birao
# Searching for record 516 | rochegda
# Searching for record 517 | manuk mangkaw
# Searching for record 518 | pitimbu
# Searching for record 519 | ongandjera
# Searching for record 520 | lebowakgomo
# Searching for record 521 | leshukonskoye
# Searching for record 522 | winnemucca
# Searching for record 523 | orichi
# Searching for record 524 | shache
# Searching for record 525 | beterou
# Searching for record 526 | havre-saint-pierre
# city weather not found, skipping to next record
# Searching for record 527 | georgetown
# city weather not found, skipping to next record
# Searching for record 528 | zurrieq
# Searching for record 529 | felipe carrillo puerto
# Searching for record 530 | menomonie
# Searching for record 531 | pascagoula
# Searching for record 532 | meadow lake
# Searching for record 533 | jackson
# Searching for record 534 | komsomolskiy
# Searching for record 535 | bantry
# Searching for record 536 | bridgetown
# Searching for record 537 | vista hermosa
# Searching for record 538 | vostok
# Searching for record 539 | manzhouli
# Searching for record 540 | ucluelet
# Searching for record 541 | petropavlovsk-kamchatskiy
# Searching for record 542 | buchanan
# Searching for record 543 | bernalillo
# Searching for record 544 | margate
# Searching for record 545 | san ignacio
# Searching for record 546 | maraba
# city weather not found, skipping to next record
# Searching for record 547 | rio das ostras
# Searching for record 548 | tenenkou
# Searching for record 549 | omboue
# Searching for record 550 | bolitoc
# Searching for record 551 | russell
# Searching for record 552 | dapaong
# Searching for record 553 | wamba
# Searching for record 554 | laguna
# Searching for record 555 | churapcha
# city weather not found, skipping to next record
# Searching for record 556 | eureka
# Searching for record 557 | urcos
# Searching for record 558 | tim

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data = {'City' : city_name,
              'Country' : country,
              'Date' : dates,
              'Cloud Cover': clouds,
              'Humidity' : humidity,
              'Maximum Temperature' : max_temp,
              'Wind Speed' : wind,
              'Latitude' : lat,
              'Longitude' : lng}
weather_df = pd.DataFrame(weather_data)
weather_df.head()
# Out:
#              City Country        Date  Cloud Cover  Humidity  \
# 0      São Filipe      CV  1602817994           35        77
# 1            Nome      US  1602817995           90        86
# 2        Lorengau      PG  1602817997          100        71
# 3  Cabo San Lucas      MX  1602817859            5        74
# 4          Barrow      US  1602818001           75        79
#
#    Maximum Temperature  Wind Speed  Latitude  Longitude
# 0                81.10       11.90     14.90     -24.50
# 1                39.20       18.34     64.50    -165.41
# 2                84.07        4.90     -2.02     147.27
# 3                82.40       11.41     22.89    -109.91
# 4                19.40       14.99     71.29    -156.79

# %%
weather_df.to_csv('weather_data.csv')

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
high_humidity = weather_df.loc[weather_df['Humidity'] > 100]
high_humidity
# Out:
# Empty DataFrame
# Columns: [City, Country, Date, Cloud Cover, Humidity, Maximum Temperature, Wind Speed, Latitude, Longitude]
# Index: []

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data['Latitude'], weather_data['Maximum Temperature'], marker='o')
plt.title('Latitude vs. Maximum Temperature')
plt.ylabel('Maximum Temperature (F)')
plt.xlabel('Latitude')
plt.grid(True)
plt.savefig('WeatherPy_Images/Temperature_vs_Lat.png')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data['Latitude'], weather_data['Humidity'], marker='o')
plt.title('Latitude vs. Humidity')
plt.ylabel('Humidity')
plt.xlabel('Latitude')
plt.grid(True)
plt.savefig('WeatherPy_Images/Humidity_vs_Lat.png')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data['Latitude'], weather_data['Cloud Cover'], marker='o')
plt.title('Latitude vs. Cloudiness')
plt.ylabel('Cloudiness')
plt.xlabel('Latitude')
plt.grid(True)
plt.savefig('WeatherPy_Images/Cloudiness_vs_Lat.png')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data['Latitude'], weather_data['Wind Speed'], marker='o')
plt.title('Latitude vs. Wind Speed')
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
plt.grid(True)
plt.savefig('WeatherPy_Images/Wind_vs_Lat.png')

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
northern_hemisphere = weather_df.loc[weather_df['Latitude'] > 0]
southern_hemisphere = weather_df.loc[weather_df['Latitude'] < 0]

# %%
x_values = northern_hemisphere.iloc[:,7]
y_values = northern_hemisphere.iloc[:,5]
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
fit = slope * x_values + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,fit,"r-")
plt.title('Northern Hemisphere - Maximum Temperature v Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature')
plt.savefig('WeatherPy_Images/North_Hem_Temperature_vs_Lat_LR.png')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere.iloc[:,7]
y_values = southern_hemisphere.iloc[:,5]
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
fit = slope * x_values + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,fit,"r-")
plt.title('Southern Hemisphere - Maximum Temperature v Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Maximum Temperature')
plt.savefig('WeatherPy_Images/South_Hem_Temperature_vs_Lat_LR.png')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere.iloc[:,7]
y_values = northern_hemisphere.iloc[:,4]
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
fit = slope * x_values + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,fit,"r-")
plt.title('Northern Hemisphere - Humidity v Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.savefig('WeatherPy_Images/North_Hem_Humidity_vs_Lat_LR.png')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere.iloc[:,7]
y_values = southern_hemisphere.iloc[:,4]
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
fit = slope * x_values + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,fit,"r-")
plt.title('Southern Hemisphere - Humidity v Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.savefig('WeatherPy_Images/South_Hem_Humidity_vs_Lat_LR.png')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere.iloc[:,7]
y_values = northern_hemisphere.iloc[:,3]
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
fit = slope * x_values + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,fit,"r-")
plt.title('Northern Hemisphere - Cloudiness v Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.savefig('WeatherPy_Images/North_Hem_Cloudiness_vs_Lat_LR.png')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere.iloc[:,7]
y_values = southern_hemisphere.iloc[:,3]
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
fit = slope * x_values + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,fit,"r-")
plt.title('Southern Hemisphere - Cloudiness v Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.savefig('WeatherPy_Images/South_Hem_Cloudiness_vs_Lat_LR.png')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere.iloc[:,7]
y_values = northern_hemisphere.iloc[:,6]
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
fit = slope * x_values + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,fit,"r-")
plt.title('Southern Hemisphere - Wind Speed v Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.savefig('WeatherPy_Images/North_Hem_Wind_vs_Lat_LR.png')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere.iloc[:,7]
y_values = southern_hemisphere.iloc[:,6]
slope, intercept, rvalue, pvalue, stderr = linregress(x_values, y_values)
fit = slope * x_values + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values,fit,"r-")
plt.title('Southern Hemisphere - Wind Speed v Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.savefig('WeatherPy_Images/South_Hem_Wind_vs_Lat_LR.png')
plt.show()
